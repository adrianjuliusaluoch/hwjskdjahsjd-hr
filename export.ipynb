# %%
# Import Packages
from google.cloud import bigquery
import pandas as pd

# %%
# Initialize Client
client = bigquery.Client(project='crypto-stocks-01')

# %%
# Define SQL Query to Retrieve Crypto Data
query = """
    SELECT * 
    FROM `crypto-stocks-01.storage.top_cryptocurrency`
    ORDER BY timestamp DESC
"""
crypto = client.query(query).to_dataframe()
crypto.to_csv("storage/cryptocurrency.csv", index=False)

# %%
# Define SQL Query to Retrieve Stocks Data
query = """
    SELECT * 
    FROM `crypto-stocks-01.storage.top_stocks`
    ORDER BY timestamp DESC
"""
stocks = client.query(query).to_dataframe()
stocks.to_csv("storage/stocks.csv", index=False)

# %%
# Create New Folder
# !mkdir storage

# %%
# Move both files to storage folder
# !cp cryptocurrency.csv storage
# !cp stocks.csv storage

# %%
# Create metadata file
# !kaggle datasets init -p storage
# Out:
# Data package template written to: storage/dataset-metadata.json

# %%
# Create the dataset
# !kaggle datasets create -p storage
# Out:
# Starting upload for file cryptocurrency.csv
# 100%|██████████████████████████████████████| 6.28M/6.28M [00:00<00:00, 15.5MB/s]
# Upload successful: cryptocurrency.csv (6MB)
# Starting upload for file stocks.csv
# 100%|██████████████████████████████████████| 9.37M/9.37M [00:00<00:00, 25.5MB/s]
# Upload successful: stocks.csv (9MB)
# Your private Dataset is being created. Please check progress at https://www.kaggle.com/datasets/adrianjuliusaluoch/hourly-crypto-stocks-market-data

# %%
# Update Dataset
# !kaggle datasets version -p storage -m "Automatic Update"
# Out:
# Starting upload for file cryptocurrency.csv
# 100%|██████████████████████████████████████| 6.28M/6.28M [00:00<00:00, 15.7MB/s]
# Upload successful: cryptocurrency.csv (6MB)
# Starting upload for file stocks.csv
# 100%|██████████████████████████████████████| 9.37M/9.37M [00:00<00:00, 22.7MB/s]
# Upload successful: stocks.csv (9MB)
# Dataset version is being created. Please check progress at https://www.kaggle.com/datasets/adrianjuliusaluoch/hourly-crypto-stocks-market-data

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7b84fef5-58db-4101-a9d2-5343142499f5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
